# %% [markdown]
# # Detecting Sentiment Based on OpenAi Solution
#
# https://openai.com/blog/unsupervised-sentiment-neuron/
#
# This solution consists on using a multiplicative LSTM (mLSTM) to simply predict the next charactere on product reviews. After training the recurrent network, use it's hidden units to train a classifier.
#
# In my case, I lack the resources and time available in OpenAi (as long as the knowledge), so I am going to do my best with a few days of training on a GeForce GTX 1060 instead of "one month across four NVIDIA Pascal GPUs [...] processing 12,500 characters per second."
#
# Instead of using amazon reviews, I will use a portuguese language review dataset obtained from https://www.kaggle.com/olistbr/brazilian-ecommerce.
#
# This project was made for the natural language processing discipline, UFPELs computer science course.

# %%
import os
import sys
import pandas as pd
raw_data = "../data/raw/"

reviews = pd.read_csv(os.path.join(raw_data, "olist_order_reviews_dataset.csv"), 
                      usecols=["review_id", "review_score", "review_comment_title", "review_comment_message"]).fillna("")
reviews = reviews[reviews.review_comment_message != ""]
reviews.head()
# Out:
#                            review_id  review_score review_comment_title  \
# 3   e64fb393e7b32834bb789ff8bb30750e             5
# 4   f7c4243c7fe1938f181bec41a392bdeb             5
# 9   8670d52e15e00043ae7de4c01cc2fe06             4            recomendo
# 12  4b49719c8a200003f700d3d986ea1a19             4
# 15  3948b09f7c818e2d86c9a546758b2335             5      Super recomendo
#
#                                review_comment_message
# 3               Recebi bem antes do prazo estipulado.
# 4   Parabéns lojas lannister adorei comprar pela I...
# 9   aparelho eficiente. no site a marca do aparelh...
# 12    Mas um pouco ,travando...pelo valor ta Boa.\r\n
# 15  Vendedor confiável, produto ok e entrega antes...

# %%
reviews.groupby("review_score").review_id.count()
# Out:
# review_score
# 1     9179
# 2     2229
# 3     3665
# 4     6034
# 5    20646
# Name: review_id, dtype: int64

# %% [markdown]
# # Define Multiplicative LSTM
#
# Model of recurrent neural network used by OpenAi people (https://arxiv.org/abs/1609.07959). Model obtained from https://discuss.pytorch.org/t/implementation-of-multiplicative-lstm/2328/5.

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F

class mLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, embed_size, output_size):
        super(mLSTM, self).__init__()

        self.hidden_size = hidden_size
        # input embedding
        self.encoder = nn.Embedding(input_size, embed_size)
        # lstm weights
        self.weight_fm = nn.Linear(hidden_size, hidden_size)
        self.weight_im = nn.Linear(hidden_size, hidden_size)
        self.weight_cm = nn.Linear(hidden_size, hidden_size)
        self.weight_om = nn.Linear(hidden_size, hidden_size)
        self.weight_fx = nn.Linear(embed_size, hidden_size)
        self.weight_ix = nn.Linear(embed_size, hidden_size)
        self.weight_cx = nn.Linear(embed_size, hidden_size)
        self.weight_ox = nn.Linear(embed_size, hidden_size)
        # multiplicative weights
        self.weight_mh = nn.Linear(hidden_size, hidden_size)
        self.weight_mx = nn.Linear(embed_size, hidden_size)
        # decoder
        self.decoder = nn.Linear(hidden_size, output_size)

    def forward(self, inp, h_0, c_0):
        # encode the input characters
        inp = self.encoder(inp)
        # calculate the multiplicative matrix
        m_t = self.weight_mx(inp) * self.weight_mh(h_0)
        # forget, input and output gates
        f_g = torch.sigmoid(self.weight_fx(inp) + self.weight_fm(m_t))
        i_g = torch.sigmoid(self.weight_ix(inp) + self.weight_im(m_t))
        o_g = torch.sigmoid(self.weight_ox(inp) + self.weight_om(m_t))
        # intermediate cell state
        c_tilda = torch.tanh(self.weight_cx(inp) + self.weight_cm(m_t))
        # current cell state
        cx = f_g * c_0 + i_g * c_tilda
        # hidden state
        hx = o_g * torch.tanh(cx)

        out = self.decoder(hx.view(1,-1))

        return out, hx, cx

    def init_hidden(self):
        h_0 = Variable(torch.zeros(1, self.hidden_size)).cuda()
        c_0 = Variable(torch.zeros(1, self.hidden_size)).cuda()
        return h_0, c_0

# %%
import random

def generate_chunk(predict_len=200, temperature=0.5):
    prime_str = "O produto"  
    hidden, cell = rnn.init_hidden()
    prime_input = char_tensor(prime_str).cuda()
    predicted = prime_str

    # prime_str é o texto inicial que o gerado irá completar
    for p in range(len(prime_str) - 1):
        _, hidden, cell = rnn(prime_input[p], hidden, cell)
    inp = prime_input[-1]
    
    for p in range(predict_len):
        output, hidden, cell = rnn(inp, hidden, cell)
        
        # Usa a temperatura para amostrar a distribuição e escolher a saída probabilísticamente
        output_dist = output.data.view(-1).div(temperature).exp()
        top_i = torch.multinomial(output_dist, 1)[0]
        
        # Adiciona o caracter predito à string de saída
        predicted_char = chr(top_i)
        predicted += predicted_char
        inp = char_tensor(predicted_char).cuda()

    return predicted

# %%
# Converte string para uma lista de inteiros
from unidecode import unidecode

def tensor2char(tensor, temperature=0.2):
    output_dist = output.data.view(-1).div(temperature).exp()
    top_i = torch.multinomial(output_dist, 1)[0]
    return chr(top_i)

def char_tensor(string):
    string = unidecode(string)
    tensor = torch.zeros(len(string)).long()
    for c in range(len(string)):
        try:
            tensor[c] = ord(string[c])
        except:
            print(c)
            raise
    return Variable(tensor)

print(char_tensor('The omega (Ω) symbol\n'))
# Out:
# tensor([ 84, 104, 101,  32, 111, 109, 101, 103,  97,  32,  40,  79,  41,  32,
#         115, 121, 109,  98, 111, 108,  10])

# %%
# Treina sobre um exemplo (i.e. uma amostragem do texto)

def train(inp, target):
    hidden = rnn.init_hidden()
    rnn.zero_grad()
    loss = 0

    inp = inp.cuda()
    hidden, cell = rnn.init_hidden()
    for c in range(len(inp)):
        output, hidden, cell = rnn(inp[c], hidden, cell)
        loss += loss_metric(output, target[c].unsqueeze(0))

    loss.backward()
    optimizer.step()

    return loss.data.item() / len(inp)

# %%
import time

n_epochs = 100000
print_every = 100
embed_size = 128 # ascii representation
hidden_size = 2048
lr = 0.0001

cuda = torch.device('cuda')

rnn = mLSTM(embed_size, hidden_size, embed_size, embed_size).cuda()

optimizer = torch.optim.Adam(rnn.parameters(), lr=lr)
loss_metric = nn.CrossEntropyLoss()

start = time.time()
all_losses = []
loss_avg = 0

dataset = list(map(char_tensor, reviews.review_comment_message.values))

# %%
for epoch in range(1, n_epochs + 1):
    for i, review in enumerate(dataset): 
        if len(review) > 2:
            try:
                loss = train(review[:-1].cuda(), review[1:].cuda())       
            except:
                print(review, len(review))
                raise
                
            loss_avg += loss

            if i % print_every == 0:
                print('[(%d %d%%) %.4f]' % (epoch, epoch / n_epochs * 100, loss))
                print(generate_chunk(predict_len = 50), '\n')
# Out:
# [(1 0%) 4.8674]
# O produto.H;@n>V3jx99[H^T9^iiJiHvx>zaV3h|}
#
# [(1 0%) 1.9085]
# O produto ente em produto pra mazo paras e mas perado as en
#
# [(1 0%) 1.8718]
# O produto o o e muito a comprado produto comprela recebinto
#
# [(1 0%) 2.0888]
# O produto compro e perecebi entregar entregue e produto no
#
# [(1 0%) 1.3835]
# O produto nao estar a prazo comendo e compreio ou produto e
#
# [(1 0%) 1.2181]
# O produto produto e teu ser em para desto essa des estimo e
#
# [(1 0%) 0.7465]
# O produto de entes do chegou chegou antrega de produto emba
#
# [(1 0%) 1.3504]
# O produto entrega e ma perfeito parabendo ponta do par cali
#
# [(1 0%) 1.0470]
# O produto com em produto sempre e produto produto o produto
#
# [(1 0%) 2.7963]
# O produto com do prazo e a que produto entregue um pora o f
#
# [(1 0%) 0.8446]
# O produto chegara estava e de prelo e e esta e tinha compre
#
# [(1 0%) 2.5005]
# O produto e produto dentregar o prazo e comprei produto e p
#
# [(1 0%) 1.4100]
# O produto e baracao tem em pora comendo correto e eu bom at
#
# [(1 0%) 1.6360]
# O produto esta e tende e a entrega a antes da e produto ent
#
# [(1 0%) 0.6745]
# O produto compra recebi o produto de comprei ser o produto
#
# [(1 0%) 1.4684]
# O produto chegou se ate atendireiro satisfeita a descrito b
#
# [(1 0%) 1.7399]
# O produto e bem a entrega nao da a de produto e de entregue
#
# [(1 0%) 1.5345]
# O produto de mento de perfeito. A entrega recebido. Punidad
#
# [(1 0%) 1.2324]
# O produto e entregue. Mas produto e atendimento preso que e
#
# [(1 0%) 0.6421]
# O produto perfeito e produto em perfeito e baladade e no pr
#
# [(1 0%) 1.0950]
# O produto e no produto com antes do prazo e nao com estou s
#
# [(1 0%) 1.0542]
# O produto e muito bom antes do prazo produto e entregue ant
#
# [(1 0%) 1.3466]
# O produto chegou no produto nao chegou nao tive compra e de
#
# [(1 0%) 0.4943]
# O produto e nao recebi produto o entregue antes do prazo e
#
# [(1 0%) 0.9083]
# O produto de produto e de qualidade do prazo de produto com
#
# [(1 0%) 0.8559]
# O produto entregue nao recebi o produto e nao comprado nao
#
# [(1 0%) 1.4567]
# O produto e de compra esperado. E O produto nao fui e tendo
#
# [(1 0%) 0.8567]
# O produto com a melhor mas de saber e meu produto e present
#
# [(1 0%) 1.3063]
# O produto antes do prazo e produto , entrega rapida por ent
#
# [(1 0%) 1.1212]
# O produto do prazo de embulado de que recomendo a devia de
#
# [(1 0%) 0.7019]
# O produto com produto controu com a entrega rapida, valor d
#
# [(1 0%) 1.2465]
# O produto chegou nao com de cabadora de atendimento de foi
#
# [(1 0%) 0.9903]
# O produto e a entregue antes do prazo. Produto e mas com os
#
# [(1 0%) 1.2131]
# O produto e as entrega transporta de falta deveria chegou a
#
# [(1 0%) 1.1966]
# O produto e nao em contro do prazo e entrega no prazo com o
#
# [(1 0%) 1.2793]
# O produto esta do produto e ate mas comprar contato de qual
#
# [(1 0%) 0.7615]
# O produto chegou muito dinheiro de entrega rapida e nao foi
#
# [(1 0%) 0.8666]
# O produto de boa qualidade e esta expectativas. Ele e a meu
#
# [(1 0%) 1.1906]
# O produto de boa qualidade e boa qualidade e de boa qualida
#
# [(1 0%) 0.5534]
# O produto chegou antes do prazo e bonito e nao recebemos an
#
# [(1 0%) 1.1768]
# O produto nao entrega antes do prazo e de otima que estava
#
# [(1 0%) 1.1428]
# O produto chegou antes do prazo esta e entrega muito de boa
#
# [(1 0%) 2.0119]
# O produto tente da entrega se nao e confiar entrega rapida.
#
# [(1 0%) 0.4022]
# O produto e a toca de mais a contato de trancia do produto
#
# [(1 0%) 1.8285]
# O produto chegou antes do prazo de entrega e nao foi entreg
#
# [(1 0%) 1.6440]
# O produto chegou antes do prazo e tentando com a entrega e
#
# [(1 0%) 1.0989]
# O produto e excelente, esta foi entregue antes do prazo e e
#
# [(1 0%) 3.1489]
# O produto e esta demora super rapido, e e nao chegou antes
#
# [(1 0%) 1.1300]
# O produto e para o produto e amei compra e recebi o produto
#
# [(1 0%) 1.2809]
# O produto nao chegou antes do prazo essa loja tinha produto
#
# [(1 0%) 0.7602]
# O produto e chegou antes do prazo. Mas o produto e era com
#
# [(1 0%) 1.7754]
# O produto muito bom esta do produto e o produto nao chegou
#
# [(1 0%) 0.9313]
# O produto e ate a entrega realizada para constativa a compr
#
# [(1 0%) 1.1108]
# O produto antes do prazo de eficiencia de entrega antes do
#
# [(1 0%) 0.9992]
# O produto e de muito bom produto e recebi o produto e o pra
#
# [(1 0%) 1.8051]
# O produto entregue ate agora na entrega foi entregue ada a
#
# [(1 0%) 0.5124]
# O produto de muito bom o produto de de informado e super ra
#
# [(1 0%) 1.4197]
# O produto chegou bem antes do prazo de entrega no prazo e e
#
# [(1 0%) 0.8931]
# O produto bom e muito bom o produto e com o produtos e nao
#
# [(1 0%) 1.1942]
# O produto nao chegou antes do prazo de bola por esta compra
#
# [(1 0%) 1.4670]
# O produto e otima qualidade!!!!!!!!!!!!!!!!!!!!
#
# Entrega
#
# [(1 0%) 0.3351]
# O produto conforme anunciado... Recomendo a contato com a t
#
# [(1 0%) 1.0530]
# O produto chegou antes do prazo estou aguardando a mercador
#
# [(1 0%) 0.1798]
# O produto e informacao do produto e bom e ate o produto e c
#
# [(1 0%) 1.2669]
# O produto e so meu produto e o produto e bom e com vendedor
#
# [(1 0%) 0.8431]
# O produto chegou no prazo e o esperado com o produto chegou
#
# [(1 0%) 0.5712]
# O produto e de entrega rapida! A compra do produto. Mas ape
#
# [(1 0%) 1.1906]
# O produto foi entregue no prazo de entrega e a nota fiscal
#
# [(1 0%) 0.9802]
# O produto e de confiavel para entrega super rapida. Porem o
#
# [(1 0%) 1.5567]
# O produto com a compra foi entregue dentro do prazo. Estou
#
# [(1 0%) 1.3896]
# O produto e o conforme recomendo a entrega de 14/08 e a cha
#
# [(1 0%) 1.0201]
# O produto chegou antes do prazo e estipulado e com bolsa de
#
# [(1 0%) 1.2060]
# O produto chegou e bom. Nao entrega antes do prazo e e comp
#
# [(1 0%) 0.8441]
# O produto antes do prazo. So atendeu com o produto e um per
#
# [(1 0%) 0.6947]
# O produto entregue antes do prazo preco com as fotos. Preci
#
# [(1 0%) 0.4999]
# O produto entregue pendente do produto nao conforme em empr
#
# [(1 0%) 0.1699]
# O produto entregue dentro do prazo de entrega antes do praz
#
# [(1 0%) 3.2919]
# O produto foi entregue perfeitando somente ainda nao tenho
#
# [(1 0%) 1.0136]
# O produto entregue muito bem embalado. Mesmo produto chegou
#
# [(1 0%) 0.6673]
# O produto com comprar na loja e para contato de atendimento
#
# [(1 0%) 0.6810]
# O produto certinho e o produto. E estou pratica e o frete p
#
# [(1 0%) 1.0895]
# O produto e entregar na mais comprado e nao recebi o produt
#
# [(1 0%) 1.3010]
# O produto de entregar na pessoa a mercadoria nao chegar ant
#
# [(1 0%) 0.1107]
# O produto de entrega foi entregue antes do prazo... uma loj
#
# [(1 0%) 0.8661]
# O produto e entrega. So atendimento e deles e sem para rece
#
# [(1 0%) 0.8779]
# O produto de acordo em qualidade da data foi entregue dentr
#
# [(1 0%) 0.7695]
# O produto e excelente atendida a entrega foi entregue dentr
#
# [(1 0%) 0.5207]
# O produto correto e era de otima qualidade e recebi o produ
#
# [(1 0%) 0.5249]
# O produto entregue antes do prazo. Ficou muito bom o produt
#
# [(1 0%) 0.9994]
# zya lannister e entre ia 13//////////
#
# [(1 0%) 0.9966]
# O produto e entregue antes do prazo. Muito bom o produto te
#
# [(1 0%) 0.6456]
# O produto e bem antes do prazo.
# Nao recebi o produto cheg
#
# [(1 0%) 1.0557]
# O produto e entrega rapida pelo prazo. Ja entrega foi muito
#
# [(1 0%) 0.7136]
# O produto chegou no prazo, esta loja e a mercadoria e entre
#
# [(1 0%) 1.2641]
# O produto em pedido nao e recebi o produto conforme anuncia
#
# [(1 0%) 0.6467]
# O produto e entregue antes do prazo e produto e sem meu ped
#
# [(1 0%) 0.4249]
# O produto de atenciosa de entrega foi rapido. Mas o produto
#
# [(1 0%) 0.5087]
# O produto chegou antes do prazo estamos a entrega do produt
#
# [(1 0%) 0.7824]
# O produto antes do prazo e entrega antes do prazo estimado.
#
# [(1 0%) 1.5053]
# O produto foi entregue antes do prazo e e de mercadoria. Pr
#
# [(1 0%) 0.9673]
# O produto e bom entregue antes do prazo estava meu produto
#
# [(1 0%) 1.2214]
# O produto e muito bom, e exatamente o produto e excelente o
#
# [(1 0%) 0.8500]
# O produto com o cliente pra chegar. Produto chegou bem ante
#
# [(1 0%) 1.6333]
# O produto que com a tesouras nao tem a incordado e entrega
#
# [(1 0%) 1.1724]
# O produto com como esta de entrega foi conforme de contato
#
# [(1 0%) 1.2094]
# O produto o comprado no prazo era de entrega foi entregue p
# [(1 0%) 0.2711]
# O produto e em perfeita. Muito obrigado. Recomendo. E produ
#
# [(1 0%) 0.8135]
# O produto chegou antes do prazo de entrega e em perfeito e
#
# [(1 0%) 1.0087]
# O produto e bem embalado e pelo que eu faltando os partes,
#
# [(1 0%) 0.9999]
# O produto foi entregue dentro do prazo estipulado e de otim
#
# [(1 0%) 0.3749]
# O produto chegou no prazo, e entrega rapida, produto no meu
#
# [(1 0%) 0.7603]
# O produto com defeito. Esta foi entregue dentro do prazo. P
#
# [(1 0%) 1.3663]
# O produto e com a entrega foi antes do prazo. Estou muito s
#
# [(1 0%) 0.9611]
# O produto de qualidade e entrega antes do prazo estimado. B
#
# [(1 0%) 0.5881]
# O produto de maneira e nao foi entregue dentro do prazo e p
#
# [(1 0%) 0.6664]
# O produto nao foi entregue antes do prazo e estou aguardand
#
# [(1 0%) 0.4090]
# O produto chegou em contato com uma compra e recebi apenas
#
# [(1 0%) 1.1702]
# O produto e entrega dentro do prazo!!!!!!!!!!!!!!!!!!!!!!!!
#
# [(1 0%) 1.6903]
# O produto chegou antes do prazo estipulado pelo site e ate
#
# [(1 0%) 0.5569]
# O produto com custo beneficio...muito bom produto e e com a
#
# [(1 0%) 1.1702]
# O produto entregue e antes do prazo e em perfeitas condicoe
#
# [(1 0%) 0.3274]
# O produto e a entrega e no prazo e em perfeitas conforme a
#
# [(1 0%) 0.6113]
# O produto e recebi as porem porem mais quando a compra pela
#
# [(1 0%) 0.4683]
# O produto conforme a compra do prazo. Perfeito.............
#
# [(1 0%) 1.3557]
# O produto foi entregue antes do prazo de entrega e entrega
#
# [(1 0%) 1.5388]
# O produto e entregue antes do prazo de entrega e entrega ra
#
# [(1 0%) 0.3686]
# O produto e de qualidade. Preciso frete para a internet est
#
# [(1 0%) 0.3172]
# O produto e chegou antes do prazo. Produto perfeito estado.
#
# [(1 0%) 0.9962]
# O produto e de boa qualidade de ter deste produto e bem emb
#
# [(1 0%) 1.0574]
# O produto e era de bola. Produto e excelente. E mais de ter
#
# [(1 0%) 0.6230]
# O produto e como descrito e nao tive problemas com o produt
#
# [(1 0%) 0.9305]
# O produto chegou antes do prazo e entregou antes do prazo e
#
# [(1 0%) 1.4814]
# O produto e otima qualidade do produto, e bonito e em uma b
#
# [(1 0%) 0.8338]
# O produto e dentro do prazo previsto e problema e de compra
#
# [(1 0%) 0.5101]
# O produto e veio com um dos experiencia que e o produto e a
#
# [(1 0%) 0.6753]
# O produto e nao estou corresponderam o processo da entrega
#
# [(1 0%) 0.0524]
# O produto e foi entregue dentro do prazo de entrega e super
#
# [(1 0%) 1.3620]
# O produto foi entregue antes do prazo e de otima qualidade

# %%
torch.save(lstm.state_dict(), "lstm.pth")
