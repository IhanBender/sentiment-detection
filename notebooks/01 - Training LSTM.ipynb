# %% [markdown]
# # Detecting Sentiment Based on OpenAi Solution
#
# https://openai.com/blog/unsupervised-sentiment-neuron/
#
# This solution consists on using a multiplicative LSTM (mLSTM) to simply predict the next charactere on product reviews. After training the recurrent network, use it's hidden units to train a classifier.
#
# In my case, I lack the resources and time available in OpenAi (as long as the knowledge), so I am going to do my best with a few days of training on a GeForce GTX 1060 instead of "one month across four NVIDIA Pascal GPUs [...] processing 12,500 characters per second."
#
# Instead of using amazon reviews, I will use a portuguese language review dataset obtained from https://www.kaggle.com/olistbr/brazilian-ecommerce.
#
# This project was made for the natural language processing discipline, UFPELs computer science course.

# %%
import os
import sys
import pandas as pd
raw_data = "../data/raw/"

reviews = pd.read_csv(os.path.join(raw_data, "olist_order_reviews_dataset.csv"), 
                      usecols=["review_id", "review_score", "review_comment_title", "review_comment_message"]).fillna("")
reviews = reviews[reviews.review_comment_message != ""]
reviews.head()
# Out:
#                            review_id  review_score review_comment_title  \
# 3   e64fb393e7b32834bb789ff8bb30750e             5
# 4   f7c4243c7fe1938f181bec41a392bdeb             5
# 9   8670d52e15e00043ae7de4c01cc2fe06             4            recomendo
# 12  4b49719c8a200003f700d3d986ea1a19             4
# 15  3948b09f7c818e2d86c9a546758b2335             5      Super recomendo
#
#                                review_comment_message
# 3               Recebi bem antes do prazo estipulado.
# 4   Parabéns lojas lannister adorei comprar pela I...
# 9   aparelho eficiente. no site a marca do aparelh...
# 12    Mas um pouco ,travando...pelo valor ta Boa.\r\n
# 15  Vendedor confiável, produto ok e entrega antes...

# %%
reviews.groupby("review_score").review_id.count()
# Out:
# review_score
# 1     9179
# 2     2229
# 3     3665
# 4     6034
# 5    20646
# Name: review_id, dtype: int64

# %% [markdown]
# # Define Multiplicative LSTM
#
# Model of recurrent neural network used by OpenAi people (https://arxiv.org/abs/1609.07959). Model obtained from https://discuss.pytorch.org/t/implementation-of-multiplicative-lstm/2328/5.

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F

class mLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, embed_size, output_size):
        super(mLSTM, self).__init__()

        self.hidden_size = hidden_size
        # input embedding
        self.encoder = nn.Embedding(input_size, embed_size)
        # lstm weights
        self.weight_fm = nn.Linear(hidden_size, hidden_size)
        self.weight_im = nn.Linear(hidden_size, hidden_size)
        self.weight_cm = nn.Linear(hidden_size, hidden_size)
        self.weight_om = nn.Linear(hidden_size, hidden_size)
        self.weight_fx = nn.Linear(embed_size, hidden_size)
        self.weight_ix = nn.Linear(embed_size, hidden_size)
        self.weight_cx = nn.Linear(embed_size, hidden_size)
        self.weight_ox = nn.Linear(embed_size, hidden_size)
        # multiplicative weights
        self.weight_mh = nn.Linear(hidden_size, hidden_size)
        self.weight_mx = nn.Linear(embed_size, hidden_size)
        # decoder
        self.decoder = nn.Linear(hidden_size, output_size)

    def forward(self, inp, h_0, c_0):
        # encode the input characters
        inp = self.encoder(inp)
        # calculate the multiplicative matrix
        m_t = self.weight_mx(inp) * self.weight_mh(h_0)
        # forget, input and output gates
        f_g = torch.sigmoid(self.weight_fx(inp) + self.weight_fm(m_t))
        i_g = torch.sigmoid(self.weight_ix(inp) + self.weight_im(m_t))
        o_g = torch.sigmoid(self.weight_ox(inp) + self.weight_om(m_t))
        # intermediate cell state
        c_tilda = torch.tanh(self.weight_cx(inp) + self.weight_cm(m_t))
        # current cell state
        cx = f_g * c_0 + i_g * c_tilda
        # hidden state
        hx = o_g * torch.tanh(cx)

        out = self.decoder(hx.view(1,-1))

        return out, hx, cx

    def init_hidden(self):
        h_0 = Variable(torch.zeros(1, self.hidden_size)).cuda()
        c_0 = Variable(torch.zeros(1, self.hidden_size)).cuda()
        return h_0, c_0

# %%
import random

def generate_chunk(predict_len=200, temperature=0.5):
    prime_str = "O produto"  
    hidden, cell = rnn.init_hidden()
    prime_input = char_tensor(prime_str).cuda()
    predicted = prime_str

    # prime_str é o texto inicial que o gerado irá completar
    for p in range(len(prime_str) - 1):
        _, hidden, cell = rnn(prime_input[p], hidden, cell)
    inp = prime_input[-1]
    
    for p in range(predict_len):
        output, hidden, cell = rnn(inp, hidden, cell)
        
        # Usa a temperatura para amostrar a distribuição e escolher a saída probabilísticamente
        output_dist = output.data.view(-1).div(temperature).exp()
        top_i = torch.multinomial(output_dist, 1)[0]
        
        # Adiciona o caracter predito à string de saída
        predicted_char = chr(top_i)
        predicted += predicted_char
        inp = char_tensor(predicted_char).cuda()

    return predicted

# %%
# Converte string para uma lista de inteiros
from unidecode import unidecode

def tensor2char(tensor, temperature=0.2):
    output_dist = output.data.view(-1).div(temperature).exp()
    top_i = torch.multinomial(output_dist, 1)[0]
    return chr(top_i)

def char_tensor(string):
    string = unidecode(string)
    tensor = torch.zeros(len(string)).long()
    for c in range(len(string)):
        try:
            tensor[c] = ord(string[c])
        except:
            print(c)
            raise
    return Variable(tensor)

print(char_tensor('The omega (Ω) symbol\n'))
# Out:
# tensor([ 84, 104, 101,  32, 111, 109, 101, 103,  97,  32,  40,  79,  41,  32,
#         115, 121, 109,  98, 111, 108,  10])

# %%
# Treina sobre um exemplo (i.e. uma amostragem do texto)

def train(inp, target):
    hidden = rnn.init_hidden()
    rnn.zero_grad()
    loss = 0

    inp = inp.cuda()
    hidden, cell = rnn.init_hidden()
    for c in range(len(inp)):
        output, hidden, cell = rnn(inp[c], hidden, cell)
        loss += loss_metric(output, target[c].unsqueeze(0))

    loss.backward()
    optimizer.step()

    return loss.data.item() / len(inp)

# %%
import time

n_epochs = 100000
print_every = 1000
embed_size = 128 # ascii representation
hidden_size = 2048
lr = 0.0001

cuda = torch.device('cuda')

rnn = mLSTM(embed_size, hidden_size, embed_size, embed_size).cuda()

optimizer = torch.optim.Adam(rnn.parameters(), lr=lr)
loss_metric = nn.CrossEntropyLoss()

start = time.time()
all_losses = []
loss_avg = 0

dataset = list(map(char_tensor, reviews.review_comment_message.values))

# %%
for epoch in range(16, n_epochs + 1):
    for i, review in enumerate(dataset): 
        if len(review) > 2:
            try:
                loss = train(review[:-1].cuda(), review[1:].cuda())       
            except:
                print(review, len(review))
                raise
                
            loss_avg += loss

            if i % print_every == 0:
                print('[(%d %d%%) %.4f]' % (epoch, epoch / n_epochs * 100, loss))
                print(generate_chunk(predict_len = 50), '\n')
# Out:
# [(1 0%) 4.8739]
# O produto'u\#="`Aq
# .tIKJ~dZ2zbSi!ezXl/D uN=~%
#
# [(1 0%) 0.8174]
# O produto e compre a entrega a restava e prazo compra de en
#
# [(1 0%) 0.6210]
# O produto de otimo que nao finha e do produto entrega a pro
#
# [(1 0%) 1.0825]
# O produto e para de nem ainda de controle e nao falta de co
#
# [(1 0%) 0.5688]
# O produto chegou antes do prazo embalagem nao compra e entr
#
# [(1 0%) 1.2697]
# O produto nao esperava do confortando e tudo perfeito e por
#
# [(1 0%) 1.1923]
# O produto nao foi entregue antes do prazo e previsto do pro
#
# [(1 0%) 1.5311]
#   produto de entrega foi entregue antes do prazo previsto.
#
# [(1 0%) 0.6744]
# O produto e chegou antes do prazo. O produto chegou no praz
#
# [(1 0%) 1.0473]
# O produto nao e funciona nao chegou no prazo. Produto chego
#
# [(1 0%) 1.5381]
# O produto veio com o produto e e entrega dentro do prazo, r
#
# [(1 0%) 1.0127]
# O produto de produto veio dentro do prazo e este produto e
#
# [(1 0%) 0.5189]
# O produto chegou antes do prazo estimado. Comprei um tempo
#
# [(1 0%) 1.0664]
# O produto que bem embalado e o produto.
#
#
# Atendendo o p
#
# [(1 0%) 0.6391]
# O produto bom e recomendo a loja. Veio com bom essa loja en
#
# [(1 0%) 0.4874]
# O produto pela foi entregue e na data prevista e recebi as
#
# [(1 0%) 0.4798]
# O produto bom, nunca tive que nao chegou agora nao e a recl
#
# [(1 0%) 1.0376]
# O produto veio com defeito e totalmente entregue no prazo e
#
# [(1 0%) 1.0499]
# O produto chegou no prazo certo, porem as outras compras e
#
# [(1 0%) 0.9104]
# O produto e nao e o produto e entregaram dentro do prazo e
#
# [(1 0%) 0.7281]
# O produto chegou no prazo e com produto, excelente entregar
#
# [(1 0%) 0.2313]
# O produto chegou antes do prazo estipulado. Produto excelen
#
# [(1 0%) 0.8729]
# O produto foi entregue antes do prazo previsto, porem veio
#
# [(1 0%) 0.8662]
# O produto nao consigo enviada em casa a cor errada. O produ
#
# [(1 0%) 0.8154]
# O produto nao chegou em uma compra de entrega foi entregue
#
# [(1 0%) 1.0703]
# O produto e de qualidade. Me seria melhor sera indisponivei
#
# [(1 0%) 0.7458]
# O produto e a entrega do produto atende a entrega que compr
#
# [(1 0%) 1.7371]
# O produto nao foi entregue no prazo. A entrega foi super ra
#
# [(1 0%) 1.2255]
# O produto e muito bom. Entrega antes do prazo, produto entr
#
# [(1 0%) 0.4346]
# O produto chegou antes do prazo e de pessima qualidade. O p
#
# [(1 0%) 0.1195]
# O produto e de qualidade, porem a nota fiscal tem comprar c
#
# [(1 0%) 0.7660]
# O produto chegou antes do prazo estabelecido e com voces e
#
# [(1 0%) 0.9409]
# O produto nao foi entregue ate agora nao recebi e o produto
#
# [(1 0%) 0.9947]
# O produto nao foi entregue ate antes do prazo estipulado pe
#
# [(1 0%) 1.2132]
# O produto veio com defeito de acordo com o dinheiro de volt
#
# [(1 0%) 0.4869]
# O produto atendeu a entrega e rapida. Recomendo............
#
# [(1 0%) 1.2314]
# O produto chegou antes do prazo e meu produto chegou antes
#
# [(1 0%) 0.5438]
# O produto nao foi entregue na minha compra e gostei da comp
#
# [(1 0%) 0.4379]
# O produto nao foi entregue e nao tinha no prazo de entrega
#
# [(1 0%) 0.6446]
# O produto e bom e sempre faco por cartucho e informaram que
#
# [(1 0%) 1.7559]
# O produto chegou com atendimento e chegou no prazo e o prod
#
# [(1 0%) 0.8959]
# O produto e bom, entregue no prazo e bem antes do prazo e c
#
# [(2 0%) 0.2701]
# O produto e o que esta faltando e ainda nao recebi o produt
#
# [(2 0%) 0.1412]
# O produto chegou em minha casa e ate agora nada, o produto
#
# [(2 0%) 0.2340]
# O produto foi entregue no prazo, mas apesar de nao consigo
#
# [(2 0%) 0.3514]
# O produto foi entregue antes do prazo, porem nao funciona c
#
# [(2 0%) 0.5400]
# O produto chegou com a descricao do produto. Entrega antes
#
# [(2 0%) 0.9813]
# O produto e bom e entregue no prazo. A entrega foi antes do
#
# [(2 0%) 0.9691]
# O produto nao foi entregue e nao tem em casa no anuncio...
#
# [(2 0%) 1.4588]
# O produto nao chegou e ainda nao recebi o produto. O produt
#
# [(2 0%) 0.7587]
# O produto nao chegou e nao consigo contendo a nota fiscal d
#
# [(2 0%) 0.8994]
# O produto chegou antes do prazo! Eu recomendo. Chegou antes
#
# [(2 0%) 1.2693]
# O produto chegou antes do prazo e em perfeito estado. Recom
#
# [(2 0%) 0.8371]
# O produto chegou em perfeito estado e bem embalado. Recomen
#
# [(2 0%) 0.5274]
# O produto foi entregue com a compra no site e ainda nao rec
#
# [(2 0%) 0.8870]
# O produto e bom e entrega foi embalado e dentro do prazo! S
#
# [(2 0%) 0.5194]
# O produto nao e o que eu queria. Elizar no site e nao receb
#
# [(2 0%) 0.3644]
# O produto foi entregue dentro do prazo, mas o produto chego
#
# [(2 0%) 0.5020]
# O produto foi entregue no prazo combinado, chegou bem antes
#
# [(2 0%) 0.8671]
# O produto veio com defeito da mesma e o que eu esperava mai
#
# [(2 0%) 0.8167]
# O produto chegou antes do prazo, produto de qualidade e ent
#
# [(2 0%) 0.7610]
# O produto nao foi entregue no prazo e entrega dentro do pra
#
# [(2 0%) 0.7168]
# O produto chegou antes da data prevista. Recomendo. Paraben
#
# [(2 0%) 0.2431]
# O produto de otima qualidade. Recomendo a loja. Parabens...
#
# [(2 0%) 0.7758]
# O produto chegou antes do prazo.
# Estou satisfeita. Obrigad
#
# [(2 0%) 0.8182]
# O produto veio bem embalado e recomendo. Recomendo. Entrega
#
# [(2 0%) 0.6485]
# O produto nao foi entregue. Pois esta de parabens pelo trab
#
# [(2 0%) 0.9342]
# O produto chegou antes do prazo e muito bom e conforme a de
#
# [(2 0%) 0.5689]
# O produto veio correto. Adorei. Recomendo... sempre comprei
#
# [(2 0%) 1.6012]
# O produto veio correto, perfeita e nao condiz com a entrega
#
# [(2 0%) 1.0655]
# O produto foi entregue dentro do prazo e o produto entregue
#
# [(2 0%) 0.3980]
# O produto chegou em perfeito estado, e bem embalado, de pes
#
# [(2 0%) 0.1192]
# O produto chegou antes do prazo e o produto veio bem embala
#
# [(2 0%) 0.7423]
# O produto nao foi entregue com uma melhor area de reclamaca
#
# [(2 0%) 0.8927]
# O produto e bom e conforme anunciado. A entrega foi rapida,
#
# [(2 0%) 0.9527]
# O produto nao foi entregue e nao foi entregue. E se posso r
#
# [(2 0%) 1.3448]
# O produto chegou antes do prazo de entrega e o produto e ot
#
# [(2 0%) 0.3873]
# O produto chegou antes do prazo previsto e entrega rapida.
#
# [(2 0%) 1.1088]
# O produto chegou com a caixa de entrega foi antes do prazo
#
# [(2 0%) 0.5104]
# O produto chegou muito bem embalado. E a estampa de chava d
#
# [(2 0%) 0.4167]
# O produto e chegou e no prazo combinado. Recomendo a todos.
#
# [(2 0%) 0.5375]
# O produto chegou em perfeito estado. Adorei! Super atencios
#
# [(2 0%) 1.7293]
# O produto nao foi entregue ate o momento ate hoje nao receb
#
# [(2 0%) 0.9000]
# O produto e muito bom e de qualidade. Atendeu minhas expect
#
# [(3 0%) 0.2365]
# O produto e muito bom. Excelente atencao e com problema e b
#
# [(3 0%) 0.1359]
# O produto e muito bom e nao veio o produto e chegou so a me
#
# [(3 0%) 0.2148]
# O produto e bom preco simples nao foi entregue. Nao estou e
#
# [(3 0%) 0.2790]
# O produto e um pouco pequeno e eu nem esta funcionando de p
#
# [(3 0%) 0.5521]
# O produto veio bem antes do prazo determinado, me deram um
#
# [(3 0%) 0.9561]
# O produto foi entregue antes do prazo estabelecido e o prod
#
# [(3 0%) 0.9988]
# O produto chegou no prazo e ainda nao veio com um pedido e
#
# [(3 0%) 1.3142]
# O produto chegou antes do prazo e em perfeito estado e praz
#
# [(3 0%) 0.7948]
# O produto chegou no prazo e conforme anunciado, chegou dent
#
# [(3 0%) 0.8540]
# O produto foi entregue em perfeitas condicoes e dentro do p
#
# [(3 0%) 1.1291]
# O produto chegou antes do prazo e em perfeitas condicoes...
#
# [(3 0%) 0.8407]
# O produto que comprei e so chegou faltando 1 produto e em d
#
# [(3 0%) 0.5613]
# O produto foi entregue no prazo e estava praticamente, pore
#
# [(3 0%) 0.7731]
# O produto veio com defeito. Por favor pago e nao receber o
#
# [(3 0%) 0.5406]
# O produto nao e informado que e produto esta incompleto e s
#
# [(3 0%) 0.3518]
# O produto esta como entregue dentro do prazo estipulado e e
#
# [(3 0%) 0.4720]
# O produto chegou antes do prazo estipulado. Recomendo. Reco
#
# [(3 0%) 0.8339]
# O produto e exatamente como esperava e em perfeitas condico
#
# [(3 0%) 0.7420]
# O produto chegou antes do prazo e em perfeito estado. Recom
#
# [(3 0%) 0.7622]
# O produto e menor do que eu esperava. Apesar de ser de alum
#
# [(3 0%) 0.6612]
# O produto e muito bonito e entrega rapida. Recomendo o vend
#
# [(3 0%) 0.2444]
# O produto chegou no prazo e e o preco e de bom compromisso.
# [(3 0%) 0.6856]
# O produto chegou antes do prazo e em perfeitas condicoes. R
#
# [(3 0%) 0.7795]
# O produto nao chegou e ate agora nao recebi o produto. A lo
#
# [(3 0%) 0.6624]
# O produto e bom, pois esta com defeito por enquanto aos cor
#
# [(3 0%) 0.8876]
# O produto e otimo, mas o correio esta com defeito. Sera que
#
# [(3 0%) 0.4729]
# O produto e como eu esperava. A compra foi entregue no praz
#
# [(3 0%) 1.5413]
# O produto foi entregue no prazo e veio conforme prometido,
#
# [(3 0%) 0.9936]
# O produto chegou antes do prazo. Parabens! Super recomendo.
#
# [(3 0%) 0.3995]
# O produto nao chegou no tempo estipuldado e com a data da d
#
# [(3 0%) 0.1227]
# O produto era pra chegar e nao funciona o produto atende a
#
# [(3 0%) 0.7485]
# O produto nao foi entregue a cor errada e a resistencia do
#
# [(3 0%) 0.8628]
# O produto chegou antes do prazo estipulado, porem nao foi e
#
# [(3 0%) 0.8239]
# O produto e bom, porem a embalagem de pessima qualidade na
#
# [(3 0%) 1.1998]
# O produto chegou antes do prazo de entrega, produto com def
#
# [(3 0%) 0.3708]
# O produto chegou antes do prazo e em perfeito estado. Recom
#
# [(3 0%) 1.0720]
# O produto entregue nao foi entregue. E agora que o produto
#
# [(3 0%) 0.4868]
# O produto foi entregue no prazo e em perfeito estado. Adore
#
# [(3 0%) 0.3752]
# O produto chegou antes do prazo, e com a entrega foi rapida
#
# [(3 0%) 0.5286]
# O produto e bom. A entrega foi rapida. Estou satisfeito com
#
# [(3 0%) 1.7158]
# O produto chegou muito antes do prazo combinado e sem nenhu
#
# [(3 0%) 0.8103]
# O produto veio com defeito que e um problema na entrega e o
#
# [(4 0%) 0.2332]
# O produto nao foi entregue. O produto foi entregue no prazo
#
# [(4 0%) 0.1397]
# O produto chegou antes do prazo estipulado, porem a capa e
#
# [(4 0%) 0.2461]
# O produto chegou com umas das descricao e nao entregaram os
#
# [(4 0%) 0.2627]
# O produto veio com defeito. Fiquei muito satisfeita com a c
#
# [(4 0%) 0.4958]
# O produto chegou antes do prazo e preco acessivel, entrega
#
# [(4 0%) 0.9319]
# O produto nao foi entregue e nao entregue ainda e nao recom
#
# [(4 0%) 0.9572]
# O produto foi entregue antes do prazo previsto. Produto exc
#
# [(4 0%) 1.4105]
# O produto nao foi entregue antes do prazo. Super recomendo
#
# [(4 0%) 0.7562]
# O produto chegou antes do prazo e tudo dentro do prazo e co
#
# [(4 0%) 0.8092]
# O produto e bom. Todas as minhas espectativas de servico e
#
# [(4 0%) 1.0473]
# O produto foi entregue no prazo e no prazo, nao foi entregu
#
# [(4 0%) 0.7864]
# O produto e muito bom e entrega rapida! Parabens pelo produ
#
# [(4 0%) 0.5354]
# O produto e muito bom, so nao e o que eu recebi o produto e
#
# [(4 0%) 0.8046]
# O produto e bom e bem fraco, mas nao e a pelicula do boleto
#
# [(4 0%) 0.5486]
# O produto e de otima qualidade e a entrega foi rapida, pore
#
# [(4 0%) 0.3401]
# O produto veio antes do prazo. Muito bom e a entrega foi ra
#
# [(4 0%) 0.4604]
# O produto chegou antes do prazo e produto de qualidade. Che
#
# [(4 0%) 0.8124]
# O produto veio com defeito. O produto e de boa qualidade. S
#
# [(4 0%) 0.7258]
# O produto e bom, entrega rapida. Produto excelente , entreg
#
# [(4 0%) 0.6679]
# O produto nao e a presente da baratheon e do vendedor pois
#
# [(4 0%) 0.7330]
# O produto chegou antes da data prevista.
# Muito satisfeita.
#
# [(4 0%) 0.1964]
# O produto chegou antes do prazo e ate agora nao foi entregu
#
# [(4 0%) 0.7087]
# O produto chegou correto e antes do prazo. Obrigado pela at
#
# [(4 0%) 0.7894]
# O produto nao chegou no prazo e nao recebi o produto e o pr
#
# [(4 0%) 0.5710]
# O produto chegou antes do prazo e em perfeitas condicoes. R
#
# [(4 0%) 0.8498]
# O produto nao foi entregue ate o dia 13/02 e a entrega era
#
# [(4 0%) 0.5240]
# O produto veio correto e nao comprar novamente com a loja e
#
# [(4 0%) 1.4465]
# O produto e bom, e um presente de ser baixo e para parecer
#
# [(4 0%) 1.0878]
# O produto chegou muito antes do prazo estipulado e eficient
#
# [(4 0%) 0.3993]
# O produto chegou bem antes do esperado. Produto muito bom e
#
# [(4 0%) 0.1204]
# O produto chegou no prazo, recomendo a todos... Produto che
#
# [(4 0%) 0.7366]
# O produto e bom, mas no prazo de entrega. Muito bom e lindo
#
# [(4 0%) 0.8857]
# O produto chegou no prazo e em perfeitas condicoes. A entre
#
# [(4 0%) 0.8805]
# O produto nao foi entregue e veio quebrado e nao consigo fa
#
# [(4 0%) 1.1493]
# O produto chegou antes do prazo e e conforme anuncio. Compr
#
# [(4 0%) 0.3548]
# O produto foi entregue em excelente para que o produto esta
#
# [(4 0%) 1.1049]
# O produto veio com defeito e entregue em dias dias depois d
#
# [(4 0%) 0.4921]
# O produto nao foi entregue no prazo e em otimo estado e pro
#
# [(4 0%) 0.4567]
# O produto ainda nao foi entregue ate agora nao recebi o pro
#
# [(4 0%) 0.4990]
# O produto nao chegou a tempo de presente e a embalagem e um
#
# [(4 0%) 1.6415]
# O produto chegou muito bem embalado e no prazo certo, mais
#
# [(4 0%) 0.7748]
# O produto veio com defeito e ate agora nao recebi o produto
#
# [(5 0%) 0.2159]
# O produto e de boa qualidade, entregue muito bem embalado,
#
# [(5 0%) 0.1250]
# O produto nao foi entregue e ainda nao tive nenhuma respost
#
# [(5 0%) 0.2179]
# O produto chegou no prazo, e com manual e de qualidade. A e
#
# [(5 0%) 0.2513]
# O produto e otimo!!! A entrega estava presente de transtorn
#
# [(5 0%) 0.4286]
# O produto chegou antes do prazo e a entrega foi rapida. Pro
#
# [(5 0%) 0.8678]
# O produto e bom, porem o produto entregue e diferente do qu
#
# [(5 0%) 0.9662]
# O produto foi entregue antes do prazo. Ainda nao testei. E
#
# [(5 0%) 1.2525]
# O produto chegou antes do prazo previsto. Recomendo. Entreg
#
# [(5 0%) 0.7306]
# O produto e bom e super fino e entrega antes do prazo. Muit
#
# [(5 0%) 0.8226]
# O produto e bom e fino e bonito. Muito bom o produto e a en
#
# [(5 0%) 1.0662]
# O produto foi entregue antes do prazo, porem o produto e bo
#
# [(5 0%) 0.7432]
# O produto chegou em perfeitas condicoes. Recomendo a loja..
#
# [(5 0%) 0.5285]
# O produto foi entregue no prazo e em perfeitas condicoes e
#
# [(5 0%) 0.7212]
# O produto e muito bom e de otima qualidade e a entrega demo
#
# [(5 0%) 0.5250]
# O produto e de otima qualidade, chegou bem antes do previst
#
# [(5 0%) 0.3300]
# O produto foi entregue antes do prazo previsto e em perfeit
#
# [(5 0%) 0.5332]
# O produto chegou antes do prazo, em perfeito estado. Recome
#
# [(5 0%) 0.7821]
# O produto chegou antes do prazo previsto e e de otima quali
#
# [(5 0%) 0.7032]
# O produto que foi entregue na minha casa e nao veio errado.
#
# [(5 0%) 0.7252]
# O produto chegou certinho dentro do prazo e em perfeito est
#
# [(5 0%) 0.6307]
# O produto veio certinho e ate antes do prazo e em perfeito
#
# [(5 0%) 0.1921]
# O produto veio com defeito nao funciona como a parte de cor
#
# [(5 0%) 0.7064]
# O produto foi entregue no prazo e chegou antes do prazo est
#
# [(5 0%) 0.7502]
# O produto nao chegou e nao foi entregue e o produto nao foi
#
# [(5 0%) 0.6715]
# O produto chegou antes do prazo e em ordem, esperava mais n
#
# [(5 0%) 0.8539]
# O produto chegou antes do prazo previsto, porem a compra e
#
# [(5 0%) 0.5031]
# O produto foi entregue antes do prazo previsto e em perfeit
#
# [(5 0%) 1.5138]
# O produto chegou conforme o prometido, e em perfeitas condi
#
# [(5 0%) 0.9820]
# O produto e muito bom e veio conforme anunciado. Super reco
#
# [(5 0%) 0.3741]
# O produto e de pessima qualidade e rapido e a entrega foi r
#
# [(5 0%) 0.1235]
# O produto chegou antes da data prevista. E muito bem atendi
#
# [(5 0%) 0.7946]
# O produto e bom e entregue antes do prazo previsto. Produto
#
# [(5 0%) 0.8447]
# O produto e muito bom e entrega antes do prazo. Estao de pa
#
# [(5 0%) 0.8519]
# O produto nao foi entregue ainda a mercadoria e nao consegu
#
# [(5 0%) 1.3303]
# O produto nao foi entregue. Faco no correio sem contato da
#
# [(5 0%) 0.3652]
# O produto chegou com a pessoa que nao recebi este meu produ
#
# [(5 0%) 1.1072]
# O produto chegou no prazo combinado e antes do prazo e e es
#
# [(5 0%) 0.4425]
# O produto chegou antes do prazo, muito bom e rapida a entre
#
# [(5 0%) 0.4050]
# O produto e bom e super recomendo. Entregue antes do prazo.
#
# [(5 0%) 0.4713]
# O produto e bonito, mas a entrega e de otima qualidade. Ame
#
# [(5 0%) 1.5304]
# O produto parece ser revoltado. E nao gostei de qualidade n
#
# [(5 0%) 0.9031]
# O produto e bom e a entrega foi bem rapido antes do prazo.
#
# [(6 0%) 0.2423]
# O produto e otimo e entrega rapida. Recomendo. A entrega fo
#
# [(6 0%) 0.1313]
# O produto chegou muito antes do prazo e em perfeitas condic
# [(6 0%) 0.2023]
# O produto e exatamente como esperava, mas com muita transpo
#
# [(6 0%) 0.2555]
# O produto chegou no prazo e em perfeitas condicoes e chegou
#
# [(6 0%) 0.4219]
# O produto chegou faltando a carga do correio, mas este prod
#
# [(6 0%) 0.8969]
# O produto e muito bom. Recomendo a todos. Chegou bem antes
#
# [(6 0%) 1.1679]
# O produto e muito bom, confortavel e com o consumidor
# Nao
#
# [(6 0%) 1.3448]
# O produto e bom e entrega super rapida. Recomendo.
# Entrega
#
# [(6 0%) 0.6423]
# O produto chegou antes do prazo previsto para entrega do pr
#
# [(6 0%) 0.7919]
# O produto nao chegou em desejario, a embalagem do produto a
#
# [(6 0%) 1.0946]
# O produto chegou com defeito e tamanho da bateria que eu co
#
# [(6 0%) 0.7685]
# O produto chegou antes do prazo e em perfeitas condicoes. R
#
# [(6 0%) 0.4606]
# O produto veio com defeito e nao e o que e mais foi entregu
#
# [(6 0%) 0.7944]
# O produto e bom porem nao consigo realizar a entrega de 500
#
# [(6 0%) 0.5420]
# O produto nao e original e a entrega foi dentro do prazo e
#
# [(6 0%) 0.3545]
# O produto nao foi entregue e nem um senao que tem que seria
#
# [(6 0%) 0.4448]
# O produto chegou antes do prazo combinado, chegou antes do
#
# [(6 0%) 0.8799]
# O produto nao e muito bom, porem poderia ser maior. A entre
#
# [(6 0%) 0.8798]
# O produto chegou nao comprado no site da lannister e muito
#
# [(6 0%) 0.8186]
# O produto nao chegou e nao tem nenhum problema dos correios
#
# [(6 0%) 0.5901]
# O produto chegou bem antes do prazo. Aceito as compras em o
#
# [(6 0%) 0.1817]
# O produto chegou no prazo e em perfeitas condicoes. Paraben
#
# [(6 0%) 0.7223]
# O produto chegou rapido, apesar da compra ate a presente da
#
# [(6 0%) 0.7246]
# O produto chegou no prazo e era bem antes do prazo estipula
#
# [(6 0%) 0.7307]
# O produto e otimo e bonito e bem embalado. Adorei volta a c
#
# [(6 0%) 0.8703]
# O produto chegou antes do prazo previsto. Entrega rapida ,
#
# [(6 0%) 0.4603]
# O produto foi entregue antes do prazo e em perfeitas condic
#
# [(6 0%) 1.5595]
# O produto e bom, loja entregue no prazo. Adorei e recomendo
#
# [(6 0%) 1.1166]
# O produto chegou antes do prazo super recomendo o produto,
#
# [(6 0%) 0.3789]
# O produto chegou antes do prazo de entrega e em perfeitas c
#
# [(6 0%) 0.1135]
# O produto veio corretamente e a qualidade do produto e muit
#
# [(6 0%) 0.6822]
# O produto e bom e a qualidade e muito bom, a entrega foi su
#
# [(6 0%) 0.8610]
# O produto nao e original, e isso nao e o que eu esperava e
#
# [(6 0%) 0.8660]
# O produto ainda nao chegou no dia seguinte da minha casa, p
#
# [(6 0%) 1.1912]
# O produto foi entregue antes do prazo. Muito satisfeita...e
#
# [(6 0%) 0.3712]
# O produto chegou antes do prazo, e tudo certo. Porem e boa
#
# [(6 0%) 1.0714]
# O produto e otimo, entregue no prazo... porem a compra foi
#
# [(6 0%) 0.4737]
# O produto chegou antes do prazo, produto conforme anuncio.
#
# [(6 0%) 0.4072]
# O produto foi entregue no prazo, e estou muito satisfeito.
#
# [(6 0%) 0.4600]
# O produto e bom e protege bem inferito e a embalagem e bom.
#
# [(6 0%) 1.5815]
# O produto e muito bom e mais rapido que o preco que eu espe
#
# [(6 0%) 0.8258]
# O produto chegou atrasado, apesar de entregar um pouco de d
#
# [(7 0%) 0.2205]
# O produto veio com defeito e nao tinha na mesma caixa para
#
# [(7 0%) 0.1395]
# O produto foi entregue antes do prazo, porem nao consegui r
#
# [(7 0%) 0.2097]
# O produto e com o anuncio nao e muito bom. A entrega foi su
#
# [(7 0%) 0.2521]
# O produto e bom, entrega rapida e produto de qualidade. A e
#
# [(7 0%) 0.4414]
# O produto chegou antes do prazo estipulado, de qualidade. P
#
# [(7 0%) 0.8790]
# O produto e bom, entregue antes do prazo estipulado. Recome
#
# [(7 0%) 0.8783]
# O produto chegou dentro do prazo e em perfeitas condicoes.
#
# [(7 0%) 1.3157]
# O produto chegou no prazo correto, entrega antes do prazo.
#
# [(7 0%) 0.6952]
# O produto veio com defeito, nao veio com pecas cortinas e r
#
# [(7 0%) 0.7635]
# O produto chegou antes do prazo. Muito bom o produto e entr
#
# [(7 0%) 1.0698]
# O produto chegou antes do prazo estabelecido. Parabens!!! P
#
# [(7 0%) 0.7681]
# O produto chegou antes do prazo, otima qualidade. Porem so
#
# [(7 0%) 0.5179]
# O produto chegou em 12 dias antes do prazo. Parabens a loja
#
# [(7 0%) 0.8535]
# O produto foi entregue antes do prazo de entrega era para d
#
# [(7 0%) 0.6039]
# O produto e de otima qualidade, porem esta funcionando com
#
# [(7 0%) 0.3798]
# O produto chegou dentro do prazo e em perfeitas condicoes.
#
# [(7 0%) 0.4442]
# O produto veio errado e de qualidade de marcar da casa. Cas
#
# [(7 0%) 0.8883]
# O produto e bom, e entrega rapida. Produto excelente por fa
#
# [(7 0%) 0.6813]
# O produto chegou em perfeitas condicoes e dentro do prazo.
#
# [(7 0%) 0.7402]
# O produto e lindo e de otima qualidade, correta parabens pe
#
# [(7 0%) 0.5711]
# O produto foi entregue antes da data prevista e a corrente
#
# [(7 0%) 0.1853]
# O produto chegou bem antes do prazo. Gostei muito do produt
#
# [(7 0%) 0.7081]
# O produto chegou muito rapido, tamanho de otima qualidade e
#
# [(7 0%) 0.7232]
# O produto foi entregue antes do prazo e conforme o anunciad
#
# [(7 0%) 0.6741]
# O produto chegou antes do prazo estipulado. Recomendo a loj
#
# [(7 0%) 0.8800]
# O produto veio era de otima qualidade, foi entregue bem ant
#
# [(7 0%) 0.5623]
# O produto chegou antes do prazo, e em perfeito estado e ant
#
# [(7 0%) 1.5672]
# O produto chegou antes do prazo, e em perfeitas condicoes.
#
# [(7 0%) 1.2422]
# O produto demorou muito antes do prazo. Excelente produto.
#
# [(7 0%) 0.3882]
# O produto chegou antes do prazo. Adorei a compra. Parabens
#
# [(7 0%) 0.1147]
# O produto chegou antes do prazo e muito bem embalado e ante
#
# [(7 0%) 0.7054]
# O produto chegou dentro do prazo e em perfeito estado. Reco
#
# [(7 0%) 0.9100]
# O produto veio com um pouco mais rapido e em perfeito estad
#
# [(7 0%) 0.9047]
# O produto chegou antes do prazo, gostei muito do atendiment
#
# [(7 0%) 1.2648]
# O produto chegou bem antes do prazo. Recomendo.... nao gost
#
# [(7 0%) 0.4567]
# O produto chegou no prazo e em perfeitas condicoes. Recomen
#
# [(7 0%) 1.1453]
# O produto entregue no prazo e tudo certo. Recomendo........
#
# [(7 0%) 0.4803]
# O produto chegou no prazo e em perfeito estado e antes do p
#
# [(7 0%) 0.4147]
# O produto chegou no prazo e em perfeito estado, muito bom.
#
# [(7 0%) 0.5079]
# O produto e bom e de otima qualidade. Tecido muito bom. Rec
#
# [(7 0%) 1.8454]
# O produto esta dentro do prazo e ate agora nao recebi o pro
#
# [(7 0%) 0.9373]
# O produto chegou com o esperado, em uma semana de anteceden
#
# [(8 0%) 0.2589]
# O produto foi entregue antes do prazo estipulado. Recomendo
#
# [(8 0%) 0.1330]
# O produto e perfeito e a entrega foi super rapida e produto
#
# [(8 0%) 0.2479]
# O produto chegou em ordem e estar com previsto e ate agora
#
# [(8 0%) 0.2877]
# O produto chegou antes do prazo. Excelente estado. Super re
#
# [(8 0%) 0.4367]
# O produto e muito bonito e entrega rapida. Super recomendo!
#
# [(8 0%) 0.9004]
# O produto chegou no prazo e em perfeito estado e o produto
#
# [(8 0%) 0.8474]
# O produto e excelente. Obrigada. Ate antes do prazo estimad
#
# [(8 0%) 1.2967]
# O produto e muito bom, mas achei que esta no preco basicado
#
# [(8 0%) 0.7494]
# O produto nao foi entregue dentro do prazo e em perfeito es
#
# [(8 0%) 0.8674]
# O produto nao foi entregue, nao consigo contato com a lanni
#
# [(8 0%) 1.2306]
# O produto e o meu produto chegou no prazo e em perfeitas co
#
# [(8 0%) 0.8469]
# O produto e um me entregaram o produto do frete que nao enc
#
# [(8 0%) 0.4999]
# O produto entregue e ate agora nao recebi o produto magual
#
# [(8 0%) 0.9997]
# O produto e chegou antes do prazo. Recomendo a loja produto
#
# [(8 0%) 0.6773]
# O produto e a loja e pra receber o produto. So apenas um pr
#
# [(8 0%) 0.4396]
# O produto e entregue muito rapido. A entrega foi rapida! Pr
#
# [(8 0%) 0.6188]
# O produto e entrega rapida..... otimo prazo e o mestou desi
#
# [(8 0%) 1.0176]
# O produto e nao chegou antes do prazo estabelecido. Recomen
#
# [(8 0%) 1.2384]
# O produto chegou no prazo e combinado com a tampa do prazo
#
# [(8 0%) 0.9091]
# O produto foi entregue no prazo. Por espero que eu esperava
#
# [(8 0%) 0.7955]
# O produto e entrega rapida e em contato antes do prazo. Est
#
# [(8 0%) 0.2165]
# O produto e bem frete. O que comprei na cor erout e o produ
#
# [(8 0%) 0.8711]
# O produto chegou no prazo e otimo produto e antes do prazo
#
# [(8 0%) 0.8358]
# O produto e bem antes do prazo. Entrega rapida , antes do p
# [(8 0%) 1.0083]
# O produto chegou no prazo e em perfeito estado. So nao enti
#
# [(8 0%) 1.0786]
# O produto foi otimo, entrega rapida. Amei o produto e a ent
#
# [(8 0%) 0.6605]
# O produto chegou antes do prazo, muito bom e recebi o produ
#
# [(8 0%) 1.6188]
# O produto so entregue antes do prazo, produto de qualidade
#
# [(8 0%) 1.6858]
# O produto e bem achei de entrega. Nao recebi o produto em c
#
# [(8 0%) 0.5120]
# O produto veio com a telente e sem a contato com a entrega,
#
# [(8 0%) 0.1168]
# O produto chegou antes do prazo e o produto chegou bem ante
#
# [(8 0%) 0.7961]
# O produto e bom de boa qualidade, e o que eu comprei outro
#
# [(8 0%) 0.9827]
# O produto e entregue no prazo estipulado tudo ok! O produto
#
# [(8 0%) 0.9751]
# O produto e bom de ver constatus diferente do que eu a prim
#
# [(8 0%) 1.2560]
# O produto chegou antes do prazo. Recomendo. Obrigada pela e
#
# [(8 0%) 0.4670]
# O produto veio com uma reclamada em adoreico. Mas nao consi
#
# [(8 0%) 1.3678]
# O produto e exelente e recomendo para minha filha nao serve
#
# [(8 0%) 0.5537]
# O produto chegou antes do prazo e o produto e muito bem ate
#
# [(8 0%) 0.5363]
# O produto nao foi entregue entrega rapida e o produto e sem
#
# [(8 0%) 0.7052]
# O produto chegou antes do prazo estabelepor de estar sempre
#
# [(8 0%) 1.7392]
# O produto foi entregue e desisti vindo de acordo com o prod
#
# [(8 0%) 1.0148]
# O produto chegou muito antes do prazo e entrega no prazo e
#
# [(9 0%) 0.2483]
# O produto e bom. Recomendo ................................
#
# [(9 0%) 0.1281]
# O produto para um produto e entrega rapido e antes do prazo
#
# [(9 0%) 0.2639]
# O produto e chegou no prazo, boa qualidade. Chegou antes do
#
# [(9 0%) 0.2976]
# O produto e bom e bom igual do meu dinheiro da comprar na l
#
# [(9 0%) 0.4457]
# O produto chegou antes do prazo estipulado, com certeza env
#
# [(9 0%) 0.9546]
# O produto e bom, mas parece que e a mesma que foi a pulseir
#
# [(9 0%) 0.8727]
# O produto chegou antes do prazo. Produto de otima qualidade
#
# [(9 0%) 1.3868]
# O produto veio com o pedido e faltando o produto como estav
#
# [(9 0%) 0.6876]
# O produto e bom. Como faco para trocar o produto nao veio n
#
# [(9 0%) 0.9493]
# O produto e muito bom comprado e atendimento parabens de se
#
# [(9 0%) 1.1912]
# O produto e bom e bonito. A capa de entrega por um produto
#
# [(9 0%) 0.8473]
# O produto e precisando do anuncio de boa qualidade. Devolve
#
# [(9 0%) 0.5928]
# O produto e lindo no prazo e excelente produto e entrega su
#
# [(9 0%) 0.9192]
# O produto ainda nao fo entregue e conforme o anuncio. Uma l
#
# [(9 0%) 0.6739]
# O produto chegou o produto antes do prazo, produto e excele
#
# [(9 0%) 0.4413]
# O produto e muito bom e a entrega foi curta e de boa qualid
#
# [(9 0%) 0.5834]
# O produto chegou antes do prazo e precisava e enviar pelo c
#
# [(9 0%) 1.0351]
# O produto chegou no prazo, entrega rapida, excelente produt
#
# [(9 0%) 1.2951]
# O produto chegou rapido e e em perfeito estado. Espero que
#
# [(9 0%) 0.9353]
# O produto chegou no prazo, falta de receber o produto chego
#
# [(9 0%) 0.7288]
# O produto chegou antes do prazo. Chegou antes do prazo... M
#
# [(9 0%) 0.2053]
# O produto chegou bem antes do prazo estipulado. O produto c
#
# [(9 0%) 0.8196]
# O produto e entregue em muito antes do prazo estei produto
#
# [(9 0%) 0.8722]
# O produto chegou em antes do prazo estipulado. A loja de ro
#
# [(9 0%) 1.1583]
# O produto ainda nao entego, pois estou dentro do prazo e es
#
# [(9 0%) 1.0602]
# O produto e entregue no prazo previsto... No prazo foi muit
#
# [(9 0%) 0.7450]
# O produto chegou com defeito de um estoque, achei muito des
#
# [(9 0%) 1.7414]
# O produto foi entregue 2 produtos e so recebi apenas um de
#
# [(9 0%) 1.4150]
# O produto e bom. Estou aguardando a troca de nao ter nada d
#
# [(9 0%) 0.5057]
# O produto veio conforme entregue dentro do prazo, e conform
#
# [(9 0%) 0.1149]
# O produto veio correto, antes do prazo da entrega foi do pr
#
# [(9 0%) 0.8880]
# O produto e e bom e melhor que o produto chegou antes do pr
#
# [(9 0%) 1.0056]
# O produto chegou corretamente diferente de um produto que e
#
# [(9 0%) 0.9189]
# O produto ate o prazo de entrega foi rapido todos a compras
#
# [(9 0%) 1.2645]
# O produto chegou antes do prazo e o produto e bom preciso d
#
# [(9 0%) 0.5348]
# O produto veio faltando o produto esta em perfeitas compras
#
# [(9 0%) 1.3345]
# O produto chegou bem antes do previsto. Super recomendo. A
#
# [(9 0%) 0.5988]
# O produto chegou bem antes do prazo e produto chegou cortan
#
# [(9 0%) 0.5497]
# O produto comprar no prazo e o produto entrega nao recebi m
#
# [(9 0%) 1.0050]
# O produto caro e nao entregue antes do prazo estar do prest
#
# [(9 0%) 2.1839]
# O produto de qualidade do prazo e entregue dentro do prazo.
#
# [(9 0%) 1.1230]
# O produto e chegou antes dos produto no prazo e entrega do
#
# [(10 0%) 0.4524]
# O produto foi entregue um produto de foram antes do prazo d
#
# [(10 0%) 0.0882]
# O produto chegou dentro do prevista do produto e mentrega.
#
# [(10 0%) 0.2920]
# O produto que confoi entrega nao recebi e com acabado iguai
#
# [(10 0%) 0.3922]
# O produto e bom, e nao centendi no prazo de recebi antes do
#
# [(10 0%) 0.4280]
# O produto e boa qualidade, e a uma companda o entrega foi b
#
# [(10 0%) 1.3163]
# O produto veio com a descararica nao recebi o produto na co
#
# [(10 0%) 1.0583]
# O produto foi entregue antes do prazo e entrega do produto
#
# [(10 0%) 1.7173]
# O produto nao recebi somente dante. Pedi de uma capaia ante
#
# [(10 0%) 0.6988]
# O produto nao recebi a compra e tinha a mercado e nao era e
#
# [(10 0%) 1.2862]
# O produto e comprei e nao recebi o produto e produto e ate
#
# [(10 0%) 1.7341]
# O produto e ja agilidae acevou o produto de correios e prec
#
# [(10 0%) 1.2528]
# O produto do prazo de entregam antes do prazo. Porem compre
#
# [(10 0%) 0.6397]
# O produto foi por que entregue antes do prazo estipuela. Pa
#
# [(10 0%) 1.2484]
# O produto e entrega a entrega a atendeu do prazo, estou den
#
# [(10 0%) 0.8296]
# O produto chegou minha entrega foi faltado. Cortina esta do
#
# [(10 0%) 0.6385]
# O produto e chegou o produto a unidade e muito conforme est
#
# [(10 0%) 0.7782]
# O produto de o produto com e de a parabens o para ser ainda
#
# [(10 0%) 1.2797]
# O produto e excelicia do produto e entrega.
# Parabens prod
#
# [(10 0%) 1.2407]
# O produto veio correto de entrega e nao recebi muito recome
#
# [(10 0%) 1.1886]
# O produto e perfeito e entregue no prazo e esta de a entreg
#
# [(10 0%) 0.8666]
# O produto chegou antes do prazo estado. A cor irrar dem me
#
# [(10 0%) 0.2092]
# O produto chegou antes do prazo de para quelva de mas a com
#
# [(10 0%) 1.0866]
# O produto veio com uma correto e nao recebi o produto e ent
#
# [(10 0%) 0.9432]
# O produto chegou anunciado contamento a a empresa e a entre
#
# [(10 0%) 1.1344]
# O produto e bom qua qualidade. Recomendo a loja. Esse tive
#
# [(10 0%) 1.3801]
# O produto chegou antes do prazo previsto de parabens, o pro
#
# [(10 0%) 0.9183]
# O produto veio com o meu pedido nao comprar a primeira pela
#
# [(10 0%) 1.9884]
# O produto veio correto de entrega e nao tenho a novamerar n
#
# [(10 0%) 2.4391]
# O produto e otima qualidade, acabamento os sempre pra minha
#
# [(10 0%) 0.6914]
# O produto chegou antes do prazo foi entregue antes do prazo
#
# [(10 0%) 0.1224]
# O produto chegou antes do prazo de entrega do prazo esta co
#
# [(10 0%) 0.9052]
# O produto e otima qualidade... so entregaram inteiros produ
#
# [(10 0%) 1.3455]
# O produto chegou e a entregue antes do produto como a entre
#
# [(10 0%) 1.2942]
# O produto e perfeito. Me agil do prazo de melha exelao da e
#
# [(10 0%) 1.6064]
# O produto nao esta os de contativel com a entrega de um cap
#
# [(10 0%) 1.0382]
# O produto da embalagem do prazo. Recomendo! Portentes do cu
#
# [(10 0%) 1.8374]
# O produto e comprei compro nao entregue mas de qualidade a
#
# [(10 0%) 0.8397]
# O produto chegou mas o produtos nao de exceliOadou no produ
#
# [(10 0%) 0.6238]
# O produto nao entrega no prazo, e mais peciso produto, foi
#
# [(10 0%) 1.2608]
# O produto entregue antes do prazo de o mesa mal da por isso
#
# [(10 0%) 2.8318]
# O produto no entregue em nase 19/03/2018 para embalado e en
#
# [(10 0%) 1.6716]
# O produto entregue perfo produto e ate antes de prazo e des
#
# [(11 0%) 0.6248]
# O produto na entrega com o anuncinao veio com o tecido de f
#
# [(11 0%) 0.1479]
# O produto entregue no prazo e nao e recomendo..............
#
# [(11 0%) 0.4556]
# O produto entregue no prazo de qualidade. O produto e de qu
# [(11 0%) 0.4199]
# O produto chegou nao estava toula de 3 dias uma de de preco
#
# [(11 0%) 0.4727]
# O produto antes do prazo e entregue no prazo e nao e a loja
#
# [(11 0%) 1.3892]
# O produto nao e chgos e meu recebi a produto e o produto de
#
# [(11 0%) 1.2067]
# O produto e muito recebi o produto dite entregar a meundo e
#
# [(11 0%) 1.7793]
# O produto chegou antes do prazo previsto e a da mas a lanni
#
# [(11 0%) 0.7328]
# O produto veio embalado, mas nao ser uma cosa na montado na
#
# [(11 0%) 1.2614]
# O produto esta da faltando de com a compra de de volcoou no
#
# [(11 0%) 1.7983]
# O produto chegou de antes do prazo, comprei compra, mas a e
#
# [(11 0%) 1.2339]
# O produto ante dias minha mesma da entrega comprar no prazo
#
# [(11 0%) 0.6516]
# O produto ante do prazo porem o produto e entrega antes do
#
# [(11 0%) 1.4764]
# O produto foi entregue antes do prazo e exrelente de qualid
#
# [(11 0%) 0.7329]
# O produto foi entregue no prazo da lannister e entrega e no
#
# [(11 0%) 0.7530]
# O produto veio devio demais do prazo. Estou aperado.
# Recom
#
# [(11 0%) 0.8154]
# O produto e boa a qualidade. Pedi tante a loja marcado. Rec
#
# [(11 0%) 1.3746]
# O produto e entrega antes do prazo, porem nao tem por um en
#
# [(11 0%) 1.7619]
# O produto chegou e antes do prazo dos pracerizado com a emp
#
# [(11 0%) 1.3494]
# O produto chegou em uma antes do prazo. Estou mais e a comp
#
# [(11 0%) 0.9133]
# O produto chegou antes do prazo mais to do prazo da qualida
#
# [(11 0%) 0.2502]
# O produto nao comprar no prazo e prazo. As muito barativel
#
# [(11 0%) 1.1942]
# O produto conforme como em perfeita condico. Fique produto
#
# [(11 0%) 0.9438]
# O produto chegou nao foi entregue bem embalado. Tem mais un
#
# [(11 0%) 1.4926]
# O produto recebi o produto na fota do produto sem nao confi
#
# [(11 0%) 1.5570]
# O produto que entro e comprar no prazo. Recebi ate agora na
#
# [(11 0%) 1.1464]
# O produto comprados. Estou  muito bom ser conecorreto e por
#
# [(11 0%) 2.2297]
# O produto e muito ao produto entregue forga pra enchegou na
#
# [(11 0%) 1.9115]
# O produto de o meu produto com entregar o produto de o praz
#
# [(11 0%) 0.6779]
# O produto e as corta nao conformentrar a compra nao esta at
#
# [(11 0%) 0.2259]
# O produto deso so Foi e bom prado. Estou mudo produto pa de
#
# [(11 0%) 1.5499]
# O produto 0/uo comprei e enteria do produto e-5precixao o p
#
# [(11 0%) 2.2375]
# O produto ch dora parabeleindo egjvcomuito que e va tr$a e
#
# [(11 0%) 1.8608]
# O produto cho e mito encoisso iestou ndora no e ficarezo at
#
# [(11 0%) 1.5627]
# O produto co ainda que e o produto chum prazo. No produto e
#
# [(11 0%) 1.4473]
# O produto cho peuper o reces o produto mco. produto vetrei
#
# [(11 0%) 2.2759]
# O produto cho e me por que comprar no produto chhvennn foi
#
# [(11 0%) 0.9812]
# O produto fde o produto ezfical, produto nte foi a prazo ac
#
# [(11 0%) 0.6923]
# O produto chegou correios, porte ende. com o preto do produ
#
# [(11 0%) 1.3890]
# O produto e 3thegoaora qualidade e stera nao recebi a entre
#
# [(11 0%) 2.7576]
# O produto aora e com mo de e mas cal a do prazo de produto
#
# [(11 0%) 1.9345]
# O produto e vbrigecomendo constark.
# Nao e conficas  foi ce
#
# [(12 0%) 0.8622]
# O produto nando produto fIcom endo e me de recebiente e e e
#
# [(12 0%) 0.1555]
# O produto chegou antes dotro,ei e parec e um produto muGo e
#
# [(12 0%) 0.6235]
# O produto nao foi e entrega rapida. Muito bom a entregaram
#
# [(12 0%) 0.5233]
# O produto e c,Uwk!stu nao entradoo produto naooi recebi meu
#
# [(12 0%) 0.4975]
# O produto chegou nao recebi o produto dentregue rapido e pr
#
# [(12 0%) 1.8009]
# O produto e vbriclamassao ser entes do para inda e comendo.
#
# [(12 0%) 1.4205]
# O produto e pxima compra es pas o mente da entrega esto a c
#
# [(12 0%) 2.0447]
# O produto e s meu pedido erete do prazo desrito e e conforr
#
# [(12 0%) 1.0445]
# O produto e tbrrin o produto. atima qualidade.
# Perfeita es
#
# [(12 0%) 1.3902]
# O produto tboa a t apencomendo e pestao agou a entregar com
#
# [(12 0%) 1.9170]
# O produto fos indecepico como foras a e a entrega foi caixa
#
# [(12 0%) 1.6721]
# O produto foi inte o prazo e e recomendo estark nao de o pr
#
# [(12 0%) 0.9653]
# O produto ve que recebi o produto mexxdo e ntrega nao receb
#
# [(12 0%) 1.7345]
# O produto e dde a capa nha de de veio com o com co prado. p
#
# [(12 0%) 1.0422]
# O produto chegou entregue muito antes do prazo previso e a
#
# [(12 0%) 0.8602]
# O produto er
# feito. Aguardo e nao compra no produto eT, pr
#
# [(12 0%) 1.0722]
# O produto ot regue no produto com um produto o a aemais sa
#
# [(12 0%) 1.5835]
# O produto chegou bem dento e produto e nndei vez entrega en
#
# [(12 0%) 1.5096]
# O produto aino e previsto..................................
#
# [(12 0%) 1.4669]
# O produto e  bjas.com nha comprar da ligadada e nao e a dev
#
# [(12 0%) 1.1318]
# O produto ve cuonho excelente. Superou mu problemara a loja
#
# [(12 0%) 0.3837]
# O produto chegou prei as perfava pelo todeimento ter de com
#
# [(12 0%) 1.5704]
# O produto chegou antes do prazo. Nutando direi adista e nom
#
# [(12 0%) 0.9749]
# O produto nao foi entrega em def a sem de e embalado, com a
#
# [(12 0%) 1.5196]
# O produto foi entregue nao e recom um com o produto e ante
#
# [(12 0%) 1.6771]
# O produto foi i entrega correio o presao eraracao da na mer
#
# [(12 0%) 1.1741]
# O produto ve conforma compra. Muito bom o recontrame a ser
#
# [(12 0%) 2.2625]
# O produto chegou corretando o produto quo de veio por para
#
# [(12 0%) 2.1577]
# O produto veio e modem produto ot daiva loja entrei de um a
#
# [(12 0%) 0.8250]
# O produto chegou antes do precebi e nao entrega no prazo pe
#
# [(12 0%) 0.1460]
# O produto e  b esta fica muito reamente, produto enolo eram
#
# [(12 0%) 1.1418]
# O produto chegou correios.
# Gsuper bom recom o produto aind
#
# [(12 0%) 1.8862]
# O produto chegou com anunciado, o produto es super do produ
#
# [(12 0%) 1.6048]
# O produto chegou comprar pelo c produto e bom a entate de p
#
# [(12 0%) 1.4960]
# O produto ve mas a de comprar tem antes do prazo, produto n
#
# [(12 0%) 1.2444]
# O produto e bomn para correio de bola da mercadoria foi ent
#
# [(12 0%) 2.0493]
# O produto este ado tecom de produto e rela esta a ftutou do
#
# [(12 0%) 0.8186]
# O produto chegou antes do prazo. CARA Vero prazo de entrega
#
# [(12 0%) 0.6131]
# O produto foatilentregue na porque a entrega e dentrega rap
#
# [(12 0%) 1.2296]
# O produto chegou correios apenderde a bem a nao se em nade
#
# [(12 0%) 2.6343]
# O produto chorega a entrega rapida, nao entrega e recebi o
#
# [(12 0%) 1.6753]
# O produto foi entregue no produto venferente de e para sem
#
# [(13 0%) 0.6918]
# O produto e bomu  chegou neir muito bom defeita. A correio
#
# [(13 0%) 0.1510]
# O produto ves emoras temeerias eu perfeita antes da dats de
#
# [(13 0%) 0.4939]
# O produto foi  bonia qualidade com veios no previstos s alg
#
# [(13 0%) 0.4122]
# O produto chegou com de produto e entrega realiza que o pro
#
# [(13 0%) 0.4980]
# O produto chegou antes do prazo, produto nea56ro de esticel
#
# [(13 0%) 1.7015]
# O produto e bomn nece nao recebi produto de qualidade nao f
#
# [(13 0%) 1.4118]
# O produto e bommar liza e e otima qualidade da loja. E mana
#
# [(13 0%) 2.1211]
# O produto e bomno produto chegou prazo de enao esta dem com
#
# [(13 0%) 1.0087]
# O produto chegou nao etro de parabela de otima qualidade. M
#
# [(13 0%) 1.3414]
# O produto chegou nao monta a derada produto nao era do praz
#
# [(13 0%) 1.8329]
# O produto chegou antes do prazo e o preco sem produto e e b
#
# [(13 0%) 1.5572]
# O produto e bomn es do ee comprei nconte mas enao e recomen
#
# [(13 0%) 0.9319]
# O produto foireci a novao e aperfeita. Paguei so produto co
#
# [(13 0%) 1.6229]
# O produto chegou nao conspra mais a comprar no que produto
#
# [(13 0%) 1.0292]
# O produto chegou comprar no produto velr  o produto es e mu
#
# [(13 0%) 0.8692]
# O produto e ti reclaminhs a do prazo do prazo.
# Recomendo!
#
# [(13 0%) 0.9708]
# O produto chegou compro ns de previsto antes do prazo. E na
#
# [(13 0%) 1.5381]
# O produto cho gostem uma compra nao de so produto quca a en
#
# [(13 0%) 1.4103]
# O produto e dpera dentrega e a entrega foi um produto e aii
#
# [(13 0%) 1.4014]
# O produto veio oboa com ar a comprei do aserio antes do pra
#
# [(13 0%) 1.1195]
# O produto e scesom pos comentar a a loja prada. Por em prev
#
# [(13 0%) 0.3691]
# O produto e s mese nao e ntrega e no produto na foi entrega
#
# [(13 0%) 1.4662]
# O produto chegou corretando chegou nu antes do prazo de meu
# [(13 0%) 0.9630]
# O produto foi entregue no produto asperava de contrei os pr
#
# [(13 0%) 1.4695]
# O produto ch entrega na pois sentregar a recomendo e espara
#
# [(13 0%) 1.6665]
# O produto nao foi derico porece de tate entregar com a de n
#
# [(13 0%) 1.1516]
# O produto veio entregouotere que a expela ze mas com tou  u
#
# [(13 0%) 2.2394]
# O produto foi entregue na entrega de so prazo e d mas o pre
#
# [(13 0%) 2.0937]
# O produto na a corta produto neio de entregue estoque com o
#
# [(13 0%) 0.7955]
# O produto chegou antes do prazo, sem da compra feito da Sum
#
# [(13 0%) 0.1452]
# O produto aoda foi ente de enterega. Recomendo.. Entrega o
#
# [(13 0%) 1.1161]
# O produto chegou cera de compra fora e o prazo e esta como
#
# [(13 0%) 1.8297]
# O produto chegou antes do produto s aimos que muito que de
#
# [(13 0%) 1.5897]
# O produto ve aeuerfeito conforme o produto fo  entrega foi
#
# [(13 0%) 1.4994]
# O produto aode compra nao comentes do prazo e embalagem a e
#
# [(13 0%) 1.2376]
# O produto foi entrega rapida. Produto beo nao corei a prazo
#
# [(13 0%) 2.0505]
# O produto chegou comprei o produto noiterto. Tudo certo e e
#
# [(13 0%) 0.7946]
# O produto veio bempor de nao entrega nao chegou a compra, p
#
# [(13 0%) 0.6114]
# O produto chegou mas nao foi com minhas ca barme a todos pa
#
# [(13 0%) 1.1930]
# O produto chegou com erando a empresa vez produto com a ent
#
# [(13 0%) 2.6242]
# O produto e dvda chegamente do prazo. A dias pareces nao  P
#
# [(13 0%) 1.6500]
# O produto foi entregue nao destava compra e e e de e entreg
#
# [(14 0%) 0.6759]
# O produto chegou muito recebi o produto estlecomendo a entr
#
# [(14 0%) 0.1506]
# O produto e  bameio e comprar com  forme o produto e engos
#
# [(14 0%) 0.4873]
# O produto foi entregue na para recebi ente o produto noRola
#
# [(14 0%) 0.3895]
# O produto chegou muito recebi apenas a compra e pretodis pr
#
# [(14 0%) 0.5048]
# O produto chegou com anunciontatso  dia compra fa e comprad
#
# [(14 0%) 1.6867]
# O produto chegou no veio e boa qualidade do produto chegunp
#
# [(14 0%) 1.4020]
# O produto chegou antes do prazo. Recebi um produto dentrega
#
# [(14 0%) 2.1347]
# O produto chegeu nde anuese produto chego confirmente a tem
#
# [(14 0%) 1.0071]
# O produto chegou compra pertos do produto nao desta com o p
#
# [(14 0%) 1.3310]
# O produto noate do moutos do pprado e nteguardando meu eles
#
# [(14 0%) 1.8215]
# O produto e bomn a entrega em pera nao e tem mais o estav d
#
# [(14 0%) 1.5364]
# O produto vema eram entro nao e com antes dos produto e no
#
# [(14 0%) 0.9274]
# O produto ve pel loja lannister cormei antes do prazo. E ma
#
# [(14 0%) 1.5913]
# O produto cho bo produto e emor a por pra produto e ite a c
#
# [(14 0%) 1.0291]
# O produto veio entrega recomendo essais recomendo o produto
#
# [(14 0%) 0.8709]
# O produto chegou produto eo entao entrega foi entrega rapid
#
# [(14 0%) 0.9551]
# O produto nao de entrega. No pque cona foti eu pois a a ate
#
# [(14 0%) 1.5233]
# O produto aodiforma nao comprar ne produto coescrecebi e no
#
# [(14 0%) 1.3650]
# O produto chegou muito bom o produto cde sem proble peque s
#
# [(14 0%) 1.3856]
# O produto e d dcentes do prazo. A qualidade exata estram  u
#
# [(14 0%) 1.1183]
# O produto e bo de parabens previsto de o recebi apender er
#
# [(14 0%) 0.3697]
# O produto choe no s iciz nao forecomprei operado a entrega
#
# [(14 0%) 1.4451]
# O produto chegou compra pentregar o corrre. Estou so esta f
#
# [(14 0%) 0.9574]
# O produto e bomn do que te antes do prazo. Recebi o produto
#
# [(14 0%) 1.4572]
# O produto chegou antes do prazo, muito bom! Obrigado nao re
#
# [(14 0%) 1.6646]
# O produto e mudda um produto peu fica de veio que a loja pr
#
# [(14 0%) 1.1503]
# O produto foi entregue no produto asuper sperados e o mater
#
# [(14 0%) 2.2430]
# O produto chegou feita entativas des de targa da trecom a d
#
# [(14 0%) 2.0610]
# O produto fa forto e entregantes do prazo , esmora ando que
#
# [(14 0%) 0.7884]
# O produto nao foi entregue nas embalada aava avaliado pe co
#
# [(14 0%) 0.1446]
# O produto chegou antes do prazo, muito bom. Otimo produto e
#
# [(14 0%) 1.1096]
# O produto na o chegou meu produto de otimo produto oico, po
#
# [(14 0%) 1.8801]
# O produto chegou em embalado produto e aeindo e recebi um d
#
# [(14 0%) 1.5853]
# O produto chegou ara?ceito a ter e a antes do prazo. Notimo
#
# [(14 0%) 1.4992]
# O produto e te muito bom defera de o para e recomendo e est
#
# [(14 0%) 1.2242]
# O produto foin apessida na entrega de entrega rapida. Estou
#
# [(14 0%) 2.1059]
# O produto chegou antes do prazo! lente com es preco baem to
#
# [(14 0%) 0.7844]
# O produto cho entregue muito mas da por com ue bom sem ante
#
# [(14 0%) 0.6150]
# O produto chegou em ante pedida comprar pel s poues a entre
#
# [(14 0%) 1.1849]
# O produto e bom,ode esta entrega no prazo e da se mas e de
#
# [(14 0%) 2.6116]
# O produto chegou em antes do prazo e chegou antes do prazo
#
# [(14 0%) 1.6455]
# O produto noe e recebi o produto chegou adorei mesmo foi en
#
# [(15 0%) 0.6686]
# O produto foi entregue nao e pedido e o produto denamais do
#
# [(15 0%) 0.1501]
# O produto chegou antes do prazo, muito bom. Obrigado. Nao s
#
# [(15 0%) 0.4806]
# O produto foi entregue no produto e neio e produto eumente
#
# [(15 0%) 0.3747]
# O produto chegou como a compra pina a com aco pemborenta, e
#
# [(15 0%) 0.4972]
# O produto chegou nao fazo.e o produto eerpecisto dentro do
#
# [(15 0%) 1.6831]
# O produto chegou as lannister do prazo esta ou recom mendo
#
# [(15 0%) 1.4031]
# O produto foi entregue rapi antes do prazo de 2482 16/03/20
#
# [(15 0%) 2.1465]
# O produto aotimo produto e exntesem de acompressos ue nao e
#
# [(15 0%) 1.0048]
# O produto nee As um contrado erando o produto pa entrega re
#
# [(15 0%) 1.3262]
# O produto aindo pra entrar com o de previstai, porem e devo
#
# [(15 0%) 1.8157]
# O produto e beomes para entregue a descricao de sail e logi
#
# [(15 0%) 1.5300]
# O produto vemo prazo erecebe receber no prazo, car vramente
#
# [(15 0%) 0.9268]
# O produto e beou na compra para comprei doi entregue. Receb
#
# [(15 0%) 1.5797]
# O produto noortar produto e nalto produto. aidade dias para
#
# [(15 0%) 1.0307]
# O produto cho gos que nao e nao recebi o produto e nao rece
#
# [(15 0%) 0.8733]
# O produto chegou e nao compra no produto eneebara chegou ca
#
# [(15 0%) 0.9500]
# O produto foi entregue no prazo e ao e pesso avei qua algua
#
# [(15 0%) 1.5165]
# O produto chegou com o produto e ao entrega a foi entrega f
#
# [(15 0%) 1.3389]
# O produto foi t entregue antes do prazo esta a A entrega fo
#
# [(15 0%) 1.3905]
# O produto noalao recomendo..... dem capara com a e foi entr
#
# [(15 0%) 1.1215]
# O produto chegou nao tesou satisfeito co prazo. Produto ex
#
# [(15 0%) 0.3690]
# O produto e b dem porem, as loja fois naoi  muito satisfeit
#
# [(15 0%) 1.4416]
# O produto chegou em ante perfeito. Recomendo com o peloja e
#
# [(15 0%) 0.9542]
# O produto chegou nao entrega entregue o produto entattvlo f
#
# [(15 0%) 1.4514]
# O produto e bom,u melho stou das o avalei e e o correto. Re
#
# [(15 0%) 1.6658]
# O produto chegou emas com numandar oate e entregencao prazo
#
# [(15 0%) 1.1468]
# O produto foisisto devios qu meulhobrei os correcomendo . R
#
# [(15 0%) 2.2272]
# O produto nao por bmesssime site do prazo de acomendo e com
#
# [(15 0%) 2.0569]
# O produto chegou antes doregaran,a que acompra fora tudas e
#
# [(15 0%) 0.7873]
# O produto atem amente produto e str aterialo para produto a
#
# [(15 0%) 0.1444]
# O produto chegou antes do prazo epa rado correi e a loja ti
#
# [(15 0%) 1.1012]
# O produto nao foi reecebida e targaryen muito bo bomendo na
#
# [(15 0%) 1.8538]
# O produto de emndero m mer bomente da devolvelado co produt
#
# [(15 0%) 1.5824]
# O produto chegou ceria seram comendo com o produto fo at er
#
# [(15 0%) 1.5027]
# O produto e bo prazo e entrega e ate se produto e compra de
#
# [(15 0%) 1.2239]
# O produto foi entregue antes do prazo. Muito bom o produto
#
# [(15 0%) 2.0118]
# O produto e bom, os cher re lugie......................rece
#
# [(15 0%) 0.7846]
# O produto cho eminha compra. Perfeito. Atis apera uma compr
#
# [(15 0%) 0.6164]
# O produto foi desta mentro de antes do prazo. E a entrega a
#
# [(15 0%) 1.1810]
# O produto foi acelha expentestiproduto er entrega rapida, p
#
# [(15 0%) 2.6065]
# O produto e bomn fos a muito prazo de entrega do prazo e em
#
# [(15 0%) 1.6390]
# O produto e bnos o ptenste o produto derecomendo a loja est
#
# [(16 0%) 0.6648]
# O produto e b foi entregue antes do prazo e conforma com o
# [(16 0%) 0.1491]
# O produto chegou muito boa ter lannister napida e da pra es
#
# [(16 0%) 0.4862]
# O produto e exave no produto ceum Vou reto produto e e otim
#
# [(16 0%) 0.3693]
# O produto chegou antes do prazo, e o que eu sola nas entreg
#
# [(16 0%) 0.4992]
# O produto chegou comprar posse seria recomente a loja, com
#
# [(16 0%) 1.6795]
# O produto chegentro do produto enterar o veio antes do prod
#
# [(16 0%) 1.4035]
# O produto chegou e produto acum empresserci a cabone e no q
#
# [(16 0%) 2.1469]
# O produto chegou com destivel para que nao entrega fora tra
#
# [(16 0%) 1.0048]
# O produto chegou nao to disato parado do prazo. E nao receb
#
# [(16 0%) 1.3221]
# O produto chegou em ante o pedido do prazo. Recebi o produt
#
# [(16 0%) 1.8214]
# O produto de emois so ue enviado, muito do prazo. Por um po
#
# [(16 0%) 1.5285]
# O produto vo que lindo para que fazar mas a entrega foi pro
#
# [(16 0%) 0.9256]
# O produto chegou. entregue muito lente pecto do prazao, ent
#
# [(16 0%) 1.5727]
# O produto cho recebi o produto nao do prazo esperade.......
#
# [(16 0%) 1.0291]
# O produto veio como e expera com esemprese nte a carto. Pel
#
# [(16 0%) 0.8745]
# O produto e v de satisfeita com a perfeir rapido ata para c
#
# [(16 0%) 0.9468]
# O produto aoda e a mais sta porem produto de o previs de e
#
# [(16 0%) 1.5091]
# O produto chegou e nao entrega do produto come o produto ch
#
# [(16 0%) 1.3426]
# O produto chegou antes do prazo, muito bom. Solicita e sati
#
# [(16 0%) 1.3843]
# O produto chegou comprar spem comprei pu pelo presta a perf
#
# [(16 0%) 1.1194]
# O produto chegou antes dos prazo. Recomendo!!!!!!!!!!!!!!!!
#
# [(16 0%) 0.3671]
# O produto chegou em e ntrega mas esta pel lidega nao compro
#
# [(16 0%) 1.4389]
# O produto veio como esta dia recebi uma casao corregue nao
#
# [(16 0%) 0.9558]
# O produto e ftm mente nao recebi a entregar a entrega rapid
#
# tensor([ 78,  97, 111,  32, 114, 101,  99, 101,  98, 105,  32, 111,  32, 112,
#         114, 111, 100, 117, 116, 111,  32,  99, 111, 114, 114, 101, 116, 111,
#          46,  13,  10,  69, 114,  97,  32, 117, 109,  32, 115, 119, 105, 116,
#          99,  32, 104, 100, 109, 105,  32, 111,  32,  99, 111, 114, 114, 101,
#         116, 111,  46,  32,  77,  97, 115,  32, 110,  97, 111,  32,  99, 104,
#         101, 103, 111, 117,  46,  13,  10,  13,  10,  77, 101,  32, 101, 110,
#         118, 105,  97, 114,  97, 109,  32, 117, 109,  32, 115, 119, 105, 116,
#         104,  32, 104, 117,  98,  32,  85,  83,  66,  46]) 108
# ------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-8-6a7f0000a22f> in <module>
#       3         if len(review) > 2:
#       4             try:
# ----> 5                 loss = train(review[:-1].cuda(), review[1:].cuda())
#       6             except:
#       7                 print(review, len(review))
#
# <ipython-input-6-59d226e4bb56> in train(inp, target)
#       9     hidden, cell = rnn.init_hidden()
#      10     for c in range(len(inp)):
# ---> 11         output, hidden, cell = rnn(inp[c], hidden, cell)
#      12         loss += loss_metric(output, target[c].unsqueeze(0))
#      13
#
# KeyboardInterrupt:

# %%
torch.save(rnn.state_dict(), "lstm.pth")
